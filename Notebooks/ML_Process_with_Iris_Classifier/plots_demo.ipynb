# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
# make the dataframe object
iris = datasets.load_iris()
iris_df = pd.DataFrame(data = iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target
# 0       0
# 1       0
# 2       0

# %%
min_values = iris_df.groupby('target').min()
max_values = iris_df.groupby('target').max()

pd.concat([min_values, max_values], keys=['min', 'max'])
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
#     target
# min 0                     4.3               2.3                1.0
#     1                     4.9               2.0                3.0
#     2                     4.9               2.2                4.5
# max 0                     5.8               4.4                1.9
#     1                     7.0               3.4                5.1
#     2                     7.9               3.8                6.9
#
#             petal width (cm)
#     target
# min 0                    0.1
#     1                    1.0
#     2                    1.4
# max 0                    0.6
#     1                    1.8
#     2                    2.5

# %%
# extract features (sepal length (cm), sepal width (cm))
X = iris.data[:, [0, 1]]
y = iris.target


plt.figure(figsize=(10,7))

colors = ['red', 'green', 'blue']
for i in range(len(colors)):
    # for each iteration we plot data with color coresponding to the target classes
    xs = X[y == i, 0]
    ys = X[y == i, 1]
    
    plt.scatter(xs, ys, c=colors[i])
    
plt.legend(iris.target_names)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
# seaborn
sns.set(style="ticks", color_codes=True)


g = sns.pairplot(iris_df, 
                 hue = 'target',
                 vars=['sepal length (cm)',
                       'sepal width (cm)',                     
                      ],
                 palette=sns.hls_palette(6, l=.6, s=.8),
                 markers=['o','x','+'],
                 height=3,
                 aspect=1.7
                )
