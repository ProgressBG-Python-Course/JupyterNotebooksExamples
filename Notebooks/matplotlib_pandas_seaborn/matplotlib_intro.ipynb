# %% [markdown]
# # Matplotlib - getting started

# %%
# %matplotlib inline 

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Overview
#
# Matplotlib is a Python library for producing **publication-quality figures**. It main assests are :
#
#  1. Interactive environments across platform (Linux, MacOS, Windows)
#  2. Makes it easy to produce static raster or vector graphics files without the need for any GUIs.
#  3. Allows full customization of the plots being created, but through its powerful defaults system plots only few lines of code are enoght to create a fully usable histograms, power spectra, bar charts, etc.
#
#
# ### Resources:
# Matplot lib has great [documentation](https://matplotlib.org/contents.html#). On the official site you can also find nice represented and structured [tutorials](https://matplotlib.org/tutorials/index.html). And a tons of examples with code and visual plots placed, of course, in the  [The Galery](https://matplotlib.org/gallery/index.html)
#
# ### Installation Notes
#
# - Anaconda users: do nothing
# - pipenv users:
# ```$ pipenv install matplotlib```
#
# #### Additional packages (only if you know you need them)
#
# - [ffmpeg](https://www.ffmpeg.org/) or [avconv](https://libav.org/avconv.html): for saving movies
# - [ImageMagick](https://www.imagemagick.org/script/index.php): for saving animated gifs, beside other usefull tools.
# - [Pillow](https://pillow.readthedocs.io) (&gt;= 3.4): for a larger selection of image file formats: JPEG, BMP, and TIFF image files
# - [LaTeX](https://www.latex-project.org/about/) and [GhostScript](https://www.ghostscript.com/) (for rendering text with LaTeX).

# %% [markdown]
# ### Example - create a simple Plot

# %%
#On X axis => numbers from 1 to 15
x = np.arange(1,16)

#On Y axis => the power of x-es
y = x**2

# let's plot the points:
plt.plot(x,y)

# if we want to see the plot and we do not use the '%matplotlib inline' magic, we have to:
plt.show()

# %% [markdown]
# ### Matplotlib and iPython
#
# The IPython kernel is designed to work seamlessly with the matplotlib plotting library to provide this functionality.
# It supports several backends to control the output of a plotting command

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %% [markdown]
# `%matplotlib inline`
#
# With this backend, the output of plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.

# %% [markdown]
# ## Basic Concepts

# %% [markdown]
# ### Figure
#
# The top level container for all the plot elements. A Figure Object contains the whole plot.
# You can have more than one Figure object.
# Reference: [Figure Class](https://matplotlib.org/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure)
#
# <img src="images/empty_figure.png" width="300">

# %% [markdown]
# ### Axes (and Subplots)
# The Axes represent an **individual drawing plot**, with its own coordinate system.
#
# **A figure can contain many Axes, but a given Axes object can only be placed in one Figure.**
#
# Subplots are Axes instances with additional methods to facilitate generating and manipulating a set of Axes within a figure. Every Subplot instance is a valid Axes Object.
#
# Reference:
#
# - [Axes Class](https://matplotlib.org/api/axes_api.html#matplotlib.axes.Axes)
#
# - [Figure.add_subplot](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure.add_subplot)
#
# - [Figure.add_axes](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure.add_axes)
#
# - [What are the differences between add_axes and add_subplot?](https://stackoverflow.com/questions/43326680/what-are-the-differences-between-add-axes-and-add-subplot)

# %%
fig = plt.figure()
fig.set_facecolor("#B15A5A")

# add a new axes at the position 1 on a grid of 2 rows and 1 column.
fig.add_subplot(211)

# add a new axes at the position 2 on a grid of 2 rows and 1 column.
fig.add_subplot(212)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Create figure and axes with [matplotlib.pyplot.subplots](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html)
#
# This wrapper method makes it convenient to create common layouts of subplots, including the enclosing figure object, in a single call. This is the preferred way of creatting fugure and axes objects.

# %%
fig, axes = plt.subplots(nrows=2)
fig.set_facecolor("#B15A5A")

plt.show()
print(f'Number of created axes: {len(axes)}')
# Out:
# Number of created axes: 2

# %% [markdown]
# ### Axes title and labels
#
# Each Axes can have a title ([Axes.set_title](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_title.html#matplotlib.axes.Axes.set_title)) and labels ([Axes.set_xlabel](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html), [Axes.set_ylabel](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylabel.html#matplotlib.axes.Axes.set_ylabel))

# %%
fig, axes = plt.subplots()
fig.set_facecolor("#B15A5A")

axes.set_title("y=sqrt(x)")

axes.set_xlabel("X",fontsize=14, color="yellow")
axes.set_ylabel("Y", rotation=0,fontsize=14, color="yellow")

axes.xaxis.set_label_coords(1.05, 0.02)
axes.yaxis.set_label_coords(0, 1.05)

# %% [markdown]
# #### Controlling style of text and labels using a dictionary
# Reference:
# - [Text properties and layout](https://matplotlib.org/stable/tutorials/text/text_props.html)
# - [fontdict](https://matplotlib.org/stable/gallery/text_labels_and_annotations/text_fontdict.html#sphx-glr-gallery-text-labels-and-annotations-text-fontdict-py)

# %%
fig, axes = plt.subplots()
fig.set_facecolor("#B15A5A")

axes.set_title("y=sqrt(x)", 
	fontdict={
		'fontsize': 30,
		'fontweight': 'bold',
		'color': 'red',
		'backgroundColor':'#999',
		'verticalalignment': 'bottom',
		# 'horizontalalignment': 'right'
	 },
	 loc='right'
)
# note that 'horizontalalignment' aligns text relative to its center position by default


axes.set_xlabel("X",fontsize=14, color="yellow")
axes.set_ylabel("Y", rotation=0,fontsize=14, color="yellow")

axes.xaxis.set_label_coords(1.05, 0.02)
axes.yaxis.set_label_coords(0, 1.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 4
#       1 fig, axes = plt.subplots()
#       2 fig.set_facecolor("#B15A5A")
# ----> 4 axes.set_title("y=sqrt(x)",
#       5 	fontdict={
#       6 		'fontsize': 30,
#       7 		'fontweight': 'bold',
#       8 		'color': 'red',
#       9 		'backgroundColor':'#999',
#      10 		'verticalalignment': 'bottom',
#      11 		# 'horizontalalignment': 'right'
#      12 	 },
#      13 	 loc='right'
#      14 )
#      15 # note that 'horizontalalignment' aligns text relative to its center position by default
#      18 axes.set_xlabel("X",fontsize=14, color="yellow")
#
# File /media/nemsys/data/projects/courses/common/JupyterNotebooksExamples/.venv/lib/python3.9/site-packages/matplotlib/axes/_axes.py:168, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     166 title.update(default)
#     167 if fontdict is not None:
# --> 168     title.update(fontdict)
#     169 title._internal_update(kwargs)
#     170 return title
#
# File /media/nemsys/data/projects/courses/common/JupyterNotebooksExamples/.venv/lib/python3.9/site-packages/matplotlib/text.py:198, in Text.update(self, kwargs)
#     196 # Update bbox last, as it depends on font properties.
#     197 bbox = kwargs.pop("bbox", sentinel)
# --> 198 super().update(kwargs)
#     199 if bbox is not sentinel:
#     200     self.set_bbox(bbox)
#
# File /media/nemsys/data/projects/courses/common/JupyterNotebooksExamples/.venv/lib/python3.9/site-packages/matplotlib/artist.py:1176, in Artist.update(self, props)
#    1168 def update(self, props):
#    1169     """
#    1170     Update this artist's properties from the dict *props*.
#    1171
#    (...)
#    1174     props : dict
#    1175     """
# -> 1176     return self._update_props(
#    1177         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File /media/nemsys/data/projects/courses/common/JupyterNotebooksExamples/.venv/lib/python3.9/site-packages/matplotlib/artist.py:1160, in Artist._update_props(self, props, errfmt)
#    1158             func = getattr(self, f"set_{k}", None)
#    1159             if not callable(func):
# -> 1160                 raise AttributeError(
#    1161                     errfmt.format(cls=type(self), prop_name=k))
#    1162             ret.append(func(v))
#    1163 if ret:
#
# AttributeError: 'Text' object has no property 'backgroundColor'

# %% [markdown]
# ### Ticks

# %% [markdown]
# Each axis has a ticks. With Matplotlib you can configure all aspects (location, formating, etc.) of the ticks

# %%
fig, axes = plt.subplots(nrows=1)
fig.set_facecolor("#B15A5A")

axes.get_xticklabels()[3].set_color("#F3FF00")

# %% [markdown]
# ### Lets put it all together

# %%
x = np.array([1,2,3,4])
y1 = x**2
y2 = x**3

axes_names = ['Axes 1', 'Axes 2']

fig, axes = plt.subplots(nrows=2)
fig.set_facecolor("#CCCCCC")

for ax, y, name,color in zip(axes, [y1, y2], axes_names, ["#00FF80","#0080FF"]):
    ax.plot(x, y, color='black')
    ax.set_title(name)
    ax.set_facecolor("#BA5E5E")
    ax.set_ylabel('Y Axis')
    ax.set_xlabel('X Axis')    


plt.setp(axes[0].spines.values(), color="#F3FF00")
plt.setp(axes[1].spines.values(), color="#00F3FF")

axes[0].get_xticklabels()[2].set_color("#F3FF00")
axes[1].get_xticklabels()[2].set_color("#00F3FF")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Matplotlib APIs
#
# 1. matplotlib.pyplot is a collection of command style functions that make Matplotlib work like MATLAB
# 2. The object-oriented API
#
# Reference: [api](https://matplotlib.org/stable/api/index.html)
#
# ### Live demos

# %%
# pyplot api:
x = np.linspace(0,10,100)
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))
plt.title('sin')
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))
plt.title('cos')
# Out:
# Text(0.5, 1.0, 'cos')

# %%
# task: produce same figure with OOP APIs

# %% [markdown]
# ### Multiple plots in single axes

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n)
Y = np.sin(2*X)

plt.plot (X, Y+1, color='blue', alpha=1.00)
plt.plot (X, Y-1, color=(0,1,0,1)) # equiv to: color='green', alpha=1.00


plt.show()

# %% [markdown]
# ## Tasks

# %% [markdown]
# You'll have to code a plot like the image below: <br>
# <img src="tasks/images/task_simple_plot.png" width="300">

# %%
### here is the data needed:
x = np.array([4, 9, 25])
y = np.sqrt(x)

labels_color = "#FF004F"
fig_facecolor = "#CCCCCC"

### your code starts here ####

# %% [markdown]
# ## State-based vs OOP Interface

# %% [markdown]
# ### Plot line using State-based interface

# %%
# DataSet1:
# x1 = np.random.randint(1,11, 10)
# y1 = np.random.randint(20,31, 10)
x1 = np.arange(1,11)
y1 = np.arange(11,21)

# DataSet2:
x2 = np.arange(-5,6)
y2 = np.arange(-5,6)

# %%
plt.plot(x1,y1,label='DataSet1')
plt.plot(x2,y2,label='DataSet2')
plt.legend()
# customize Figure attributes:
plt.title('My first line')
plt.xlabel('X',labelpad=50,loc="right")
plt.ylabel('Y',labelpad=20,loc="top")
_=plt.xticks(np.array(np.arange(-5,11)))
# _=plt.xticks(np.array([-5,5,10]),['a','b','c'])

# %% [markdown]
# ### Plot line using OOP interface

# %%
fig, [ax1,ax2] = plt.subplots(2)

ax1.plot(x1,y1,'or') #'[marker][line][color]'
ax1.plot(x2,y2,'g^')
ax1.set_title('My first line')
ax1.set_xlabel('X',labelpad=50,loc="right")
ax1.set_ylabel('Y',labelpad=20,loc="top")
# Out:
# Text(0, 1, 'Y')

# %% [markdown]
# ## Examples

# %%
# demo for pie plot:
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0.4, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels)

plt.show()
