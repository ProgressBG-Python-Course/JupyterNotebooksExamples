# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Numpy and Pandas with examples

# %% [markdown]
# ## Read/Write to various file formats

# %% [markdown]
# ### From CSV

# %%
# nap1 = pd.read_csv('../../datasets/NAP/TR02_OUTLET_TINS.csv', dtype={'CR02_DATE_OPENED': pd.Int64Dtype()})
nap1 = pd.read_csv('../../datasets/NAP/TR02_OUTLET_TINS.csv')
nap1.head(3)
# Out:
#    CR01_TIN_ID  CR02_EMAIL  CR02_WEB_SITE  CR02_TELEX_NO  CR02_FAX_NUMBER  \
# 0    324852794         NaN            NaN            NaN              NaN
# 1    324852795         NaN            NaN            NaN              NaN
# 2    324852796         NaN            NaN            NaN              NaN
#
#    CR02_TRADE_NAME         CR02_OUTLET_NAME CR02_DATE_OPENED  \
# 0              NaN  КАТИНА ХРИСТОВА ШАРКОВА              NaN
# 1              NaN    РУСА СТОЯНОВА ИВАНОВА              NaN
# 2              NaN   СТОЯН ДИМИТРОВ ТОДОРОВ              NaN
#
#    CR02_OUTLET_CODE  CG03_OUTLET_TYPE  CR02_DATE_CLOSED  CG04_GROUP_SECTOR  \
# 0                 0             21905               NaN                NaN
# 1                 0             21905               NaN                NaN
# 2                 0             21905               NaN                NaN
#
#    CR02_PHONE_NUMBER  CR02_MOBILE_NUMBER  CG03_OUTLET_STATUS  \
# 0                NaN                 NaN               30603
# 1                NaN                 NaN               30603
# 2                NaN                 NaN               30603
#
#    CR02_FAX_AREA_CODE  CR02_PHONE_AREA_CODE CR02_AUDIT_TRAIL_USER  \
# 0                 NaN                   NaN               AR GRAO
# 1                 NaN                   NaN               AR GRAO
# 2                 NaN                   NaN               AR GRAO
#
#   CR02_AUDIT_TRAIL_DATE CR02_AUDIT_TRAIL_ACTION
# 0            2012-09-13  Automatic registration
# 1            2012-10-12  Automatic registration
# 2            2014-04-10  Automatic registration

# %% [markdown]
# ### From JSON

# %%
authors_json_df = pd.read_json('../../datasets/python_books/authors.json')
authors_json_df.head(3)
# Out:
#             author                                          authorUrl
# 0      Mike Pirnat                            http://mike.pirnat.com/
# 1      David Mertz  http://www.oreilly.com/programming/free/functi...
# 2  Muhammad Yasoob                             http://pythontips.com/

# %% [markdown]
# ### From SQL

# %% [markdown]
# Make sure you have created the database and the user. If you want to follow the examples, you can import '../../datasets/sql_dbs/python_books.sql' like:
#
# `mysql -u userName -p -f < python_books.sql`

# %%
from sqlalchemy import create_engine
import pymysql

# create_engine(dialect+driver://username:password@host:port/database)
sql_engine = create_engine('mysql+pymysql://test:test1234@localhost/TestDB', pool_recycle=3600)
dbConn = sql_engine.connect()

authors_sql_df = pd.read_sql("select * from python_books", dbConn);
authors_sql_df
# Out:
#     id       author authorUrl
# 0  151  TEST AUTHOR  TEST URL

# %% [markdown]
# ### To CSV

# %%
# write to CSV:
authors_json_df.to_csv('./authors.csv', sep=',', encoding='utf-8', index=False)

# let's check the file
authors_csv_df = pd.read_csv('./authors.csv')
authors_csv_df.head(3)
# Out:
#             author                                          authorUrl
# 0      Mike Pirnat                            http://mike.pirnat.com/
# 1      David Mertz  http://www.oreilly.com/programming/free/functi...
# 2  Muhammad Yasoob                             http://pythontips.com/

# %% [markdown]
# ### To SQL

# %%
# # let's see the row json file
# json_file = '../../datasets/python_books/authors.json'

# f = open(json_file)
# print(f.read(300))

# %%
authors_csv_df.head(3)

# authors_csv_df.drop(columns=['Unnamed: 0'], inplace=True)
# Out:
#             author                                          authorUrl
# 0      Mike Pirnat                            http://mike.pirnat.com/
# 1      David Mertz  http://www.oreilly.com/programming/free/functi...
# 2  Muhammad Yasoob                             http://pythontips.com/

# %%
authors_csv_df.to_sql('python_books', con=sql_engine, if_exists='append', index=False)

# %% [markdown]
# ## Analyse  data in a DataFrame

# %%
# remind the nap dataframe
nap1.head()
# Out:
#    CR01_TIN_ID  CR02_EMAIL  CR02_WEB_SITE  CR02_TELEX_NO  CR02_FAX_NUMBER  \
# 0    324852794         NaN            NaN            NaN              NaN
# 1    324852795         NaN            NaN            NaN              NaN
# 2    324852796         NaN            NaN            NaN              NaN
# 3    324852797         NaN            NaN            NaN              NaN
# 4    324852798         NaN            NaN            NaN              NaN
#
#    CR02_TRADE_NAME           CR02_OUTLET_NAME CR02_DATE_OPENED  \
# 0              NaN    КАТИНА ХРИСТОВА ШАРКОВА              NaN
# 1              NaN      РУСА СТОЯНОВА ИВАНОВА              NaN
# 2              NaN     СТОЯН ДИМИТРОВ ТОДОРОВ              NaN
# 3              NaN   ИВАНКА ХРИСТОВА НИКОЛОВА              NaN
# 4              NaN  КАТЕРИНА ТОДОРОВА МРЪЧЕВА              NaN
#
#    CR02_OUTLET_CODE  CG03_OUTLET_TYPE  CR02_DATE_CLOSED  CG04_GROUP_SECTOR  \
# 0                 0             21905               NaN                NaN
# 1                 0             21905               NaN                NaN
# 2                 0             21905               NaN                NaN
# 3                 0             21905               NaN                NaN
# 4                 0             21905               NaN                NaN
#
#    CR02_PHONE_NUMBER  CR02_MOBILE_NUMBER  CG03_OUTLET_STATUS  \
# 0                NaN                 NaN               30603
# 1                NaN                 NaN               30603
# 2                NaN                 NaN               30603
# 3                NaN                 NaN               30601
# 4                NaN                 NaN               30603
#
#    CR02_FAX_AREA_CODE  CR02_PHONE_AREA_CODE CR02_AUDIT_TRAIL_USER  \
# 0                 NaN                   NaN               AR GRAO
# 1                 NaN                   NaN               AR GRAO
# 2                 NaN                   NaN               AR GRAO
# 3                 NaN                   NaN               DM GRAO
# 4                 NaN                   NaN               AR GRAO
#
#   CR02_AUDIT_TRAIL_DATE CR02_AUDIT_TRAIL_ACTION
# 0            2012-09-13  Automatic registration
# 1            2012-10-12  Automatic registration
# 2            2014-04-10  Automatic registration
# 3            2006-12-26          Data migration
# 4            2013-08-01  Automatic registration

# %%
# check for missing (NaN) values
nap1.isna().sum()
# Out:
# CR01_TIN_ID                     0
# CR02_EMAIL                 455063
# CR02_WEB_SITE              455063
# CR02_TELEX_NO              455063
# CR02_FAX_NUMBER            455063
# CR02_TRADE_NAME            455063
# CR02_OUTLET_NAME                0
# CR02_DATE_OPENED           455062
# CR02_OUTLET_CODE                0
# CG03_OUTLET_TYPE                0
# CR02_DATE_CLOSED           455063
# CG04_GROUP_SECTOR          455063
# CR02_PHONE_NUMBER          455063
# CR02_MOBILE_NUMBER         455063
# CG03_OUTLET_STATUS              0
# CR02_FAX_AREA_CODE         455063
# CR02_PHONE_AREA_CODE       455063
# CR02_AUDIT_TRAIL_USER           0
# CR02_AUDIT_TRAIL_DATE           0
# CR02_AUDIT_TRAIL_ACTION         0
# dtype: int64

# %%
# get df detailed info:
nap1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455063 entries, 0 to 455062
# Data columns (total 20 columns):
# CR01_TIN_ID                455063 non-null int64
# CR02_EMAIL                 0 non-null float64
# CR02_WEB_SITE              0 non-null float64
# CR02_TELEX_NO              0 non-null float64
# CR02_FAX_NUMBER            0 non-null float64
# CR02_TRADE_NAME            0 non-null float64
# CR02_OUTLET_NAME           455063 non-null object
# CR02_DATE_OPENED           1 non-null object
# CR02_OUTLET_CODE           455063 non-null int64
# CG03_OUTLET_TYPE           455063 non-null int64
# CR02_DATE_CLOSED           0 non-null float64
# CG04_GROUP_SECTOR          0 non-null float64
# CR02_PHONE_NUMBER          0 non-null float64
# CR02_MOBILE_NUMBER         0 non-null float64
# CG03_OUTLET_STATUS         455063 non-null int64
# CR02_FAX_AREA_CODE         0 non-null float64
# CR02_PHONE_AREA_CODE       0 non-null float64
# CR02_AUDIT_TRAIL_USER      455063 non-null object
# CR02_AUDIT_TRAIL_DATE      455063 non-null object
# CR02_AUDIT_TRAIL_ACTION    455063 non-null object
# dtypes: float64(11), int64(4), object(5)
# memory usage: 69.4+ MB

# %% [markdown]
# ## Search data in DataFrame

# %%
# search string in cells:
import re
regex = re.compile(r'КАТИНА.*ХРИСТОВА', re.IGNORECASE)
mask = nap1.CR02_OUTLET_NAME.str.contains(regex)
nap1[mask].head()
# Out:
#        CR01_TIN_ID  CR02_EMAIL  CR02_WEB_SITE  CR02_TELEX_NO  CR02_FAX_NUMBER  \
# 0        324852794         NaN            NaN            NaN              NaN
# 1739     324849340         NaN            NaN            NaN              NaN
# 27322    324881024         NaN            NaN            NaN              NaN
# 71182    324924802         NaN            NaN            NaN              NaN
# 87742    324937995         NaN            NaN            NaN              NaN
#
#        CR02_TRADE_NAME            CR02_OUTLET_NAME CR02_DATE_OPENED  \
# 0                  NaN     КАТИНА ХРИСТОВА ШАРКОВА              NaN
# 1739               NaN   КАТИНА ДИМИТРОВА ХРИСТОВА              NaN
# 27322              NaN    КАТИНА ХРИСТОВА ХРИСТОВА              NaN
# 71182              NaN     КАТИНА ИВАНОВА ХРИСТОВА              NaN
# 87742              NaN  КАТИНА АНАСТАСОВА ХРИСТОВА              NaN
#
#        CR02_OUTLET_CODE  CG03_OUTLET_TYPE  CR02_DATE_CLOSED  \
# 0                     0             21905               NaN
# 1739                  0             21905               NaN
# 27322                 0             21905               NaN
# 71182                 0             21905               NaN
# 87742                 0             21905               NaN
#
#        CG04_GROUP_SECTOR  CR02_PHONE_NUMBER  CR02_MOBILE_NUMBER  \
# 0                    NaN                NaN                 NaN
# 1739                 NaN                NaN                 NaN
# 27322                NaN                NaN                 NaN
# 71182                NaN                NaN                 NaN
# 87742                NaN                NaN                 NaN
#
#        CG03_OUTLET_STATUS  CR02_FAX_AREA_CODE  CR02_PHONE_AREA_CODE  \
# 0                   30603                 NaN                   NaN
# 1739                30601                 NaN                   NaN
# 27322               30603                 NaN                   NaN
# 71182               30603                 NaN                   NaN
# 87742               30603                 NaN                   NaN
#
#       CR02_AUDIT_TRAIL_USER CR02_AUDIT_TRAIL_DATE CR02_AUDIT_TRAIL_ACTION
# 0                   AR GRAO            2012-09-13  Automatic registration
# 1739                DM GRAO            2006-12-26          Data migration
# 27322               AR GRAO            2017-03-09  Automatic registration
# 71182               AR GRAO            2010-02-10  Automatic registration
# 87742               AR GRAO            2017-06-15  Automatic registration
